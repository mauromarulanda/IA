# %%
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('./Salary Data.csv')
data
# Out:
#       Age  Gender Education Level                      Job Title
# 0    32.0    Male      Bachelor's              Software Engineer  \
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
linear_model = smf.ols(formula = 'Age ~ Salary', data = data).fit()

# %%
linear_model.params
# Out:
# Intercept    23.837737
# Salary        0.000135
# dtype: float64

# %%
linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    Age   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     2114.
# Date:                Thu, 13 Apr 2023   Prob (F-statistic):          2.75e-155
# Time:                        23:31:31   Log-Likelihood:                -903.56
# No. Observations:                 373   AIC:                             1811.
# Df Residuals:                     371   BIC:                             1819.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     23.8377      0.328     72.714      0.000      23.193      24.482
# ...

# %%
salary_pred = linear_model.predict(pd.DataFrame(data['Salary']))
salary_pred
# Out:
# 0      36.002016
# 1      32.623049
# 2      44.111535
# 3      31.947256
# 4      50.869467
#          ...
# 370    35.326222
# 371    46.814708
# 372    29.244083
# 373    36.002016
# 374    44.111535
# Length: 375, dtype: float64

# %%
data.plot(kind = 'scatter', x = 'Age', y = 'Salary')
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
import matplotlib.pyplot as plt

plt.ylabel("Salary")
plt.xlabel("Age")
plt.scatter(data["Age"], data["Salary"], color="blue")
plt.show()

# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np

# Cargar los datos desde un archivo CSV y eliminar filas con valores faltantes
datos = pd.read_csv("./Salary Data.csv").dropna()

age = datos["Age"].values.reshape((-1, 1))
salary = datos["Salary"]

regresion = linear_model.LinearRegression()

modelo = regresion.fit(age, salary)

print("Intersección (b)", modelo.intercept_)
print("Pendiente (m)", modelo.coef_)

entrada = [[25],[30], [35], [40], [45], [50]]
prediccion = modelo.predict(entrada)
print("Predicciones:", prediccion)

plt.ylabel("Salary")
plt.xlabel("Age")
plt.scatter(age, salary, color="blue", alpha=0.55)
plt.scatter(entrada, modelo.predict(entrada), color="red")

# Trazar la línea de regresión lineal
plt.plot(age, modelo.predict(age), color="red", linewidth=3)

plt.show()
# Out:
# Intersección (b) -135021.17727346512
# Pendiente (m) [6294.10178506]
# Predicciones: [ 22331.36735303  53801.87627832  85272.38520362 116742.89412892
#  148213.40305422 179683.91197952]
